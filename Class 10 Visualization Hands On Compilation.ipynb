# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('Cars')
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %% [markdown]
# ### Q1.Create scatter plots for the following data, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced. a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand.

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.scatterplot(x = 'mpg', y = 'hp', data = df)
# plt.scatter(df['mpg'], df['hp']) for matplotlib plotting
plt.subplot(2,2,2)
sns.scatterplot(x = 'mpg', y = 'weightlbs', data = df)
plt.subplot(2,2,3)
sns.scatterplot(x = 'hp', y = 'mpg', data = df)
plt.subplot(2,2,4)
sns.scatterplot(x = 'hp', y = 'time-to-60', data = df)
plt.show()

# %%
# In Matplotlib you need to pass the 'xlabel' and 'ylabel' , whereas in Sns it is directly added

# %% [markdown]
# ### Q2. Create bar plots for the following, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced. a. Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands. b. Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, for each brand.

# %%
plt.figure(figsize=(12,11))

plt.subplot(2, 2, 1)
plt.bar(df['cylinders'], df['hp'])
plt.xlabel('Cylinders')  
plt.ylabel('hp')          
plt.title('Cylinder vs HP')

plt.subplot(2, 2, 2)  
plt.bar(df['cylinders'], df['mpg'])
plt.xlabel('Cylinders')  
plt.ylabel('mpg')          
plt.title('Cylinder vs MPG')

plt.subplot(2, 2, 3)
plt.bar(df['cylinders'], df['weightlbs'])
plt.xlabel('Cylinders')  
plt.ylabel('weightlbs')    
plt.title('Cylinder vs WeightLBS')

plt.subplot(2, 2, 4)
plt.bar(df['cylinders'], df['time-to-60'])
plt.xlabel('Cylinders')   
plt.ylabel('timeto60')   
plt.title('Cylinder vs TimeTo60')

plt.show()

# %%
# Since we have to consider the 'Brand' aspect also, we'll need to use the SNS since hue parameter exists 
# in Sns.barpplot and not plt.bar

# %%
plt.figure(figsize = (12,11))
plt.subplot(2,2,1)
sns.barplot(x = 'cylinders', y = 'hp', hue = 'brand', data = df)

plt.subplot(2,2,2)
sns.barplot(x = 'cylinders', y = 'mpg', hue = 'brand', data = df)

plt.subplot(2,2,3)
sns.barplot(x = 'cylinders', y = 'weightlbs', hue = 'brand', data = df)

plt.subplot(2,2,4)
sns.barplot(x = 'cylinders', y = 'time-to-60', hue = 'brand', data = df)

plt.show()

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
# Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, 
# for each brand. To check for parameters put a 'comma and press Shift+tab+tab' shortcut(imp). 
# Dont forget to place the cursor near the funtion

plt.figure(figsize = (13,6))
plt.subplot(2,2,1)
sns.barplot(x = 'year', y = 'hp', hue = 'brand', data = df)

plt.subplot(2,2,2)
sns.barplot(x = 'year', y = 'mpg', hue = 'brand', data = df)

plt.subplot(2,2,3)
sns.barplot(x = 'year', y = 'weightlbs', hue = 'brand', data = df)

plt.subplot(2,2,4)
sns.barplot(x = 'year', y = 'time-to-60', hue = 'brand', data = df)

plt.show()

# %% [markdown]
# ### Q3 Create pair plots for the entire data to study various patterns in the data. a. Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
# Pairplot can be plotted using 'SNS' and has the layout that is same as a 'Heatmap'.
# The main use of it is in determing the relationship of one column with other i.e., if there is high dependency of one columns 
# On another (multi-collinearity) so we can remove them. For example, if 'hp' range is from 100-300 but we increase it to 1000.
# Then, cylinders that show high multicollinearity will also show an increase in numbe though the numbers of cylinders are limited.
# So to avoid unwanted or unnecessary errors we can remove one of the columns.

# Alternatively, you can go for 'Correlation'.

sns.pairplot(df)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# We choose hue to categorize the data for example, brand has 3 values (US, Japan, Europe). Hue will help us distinguish 
# Between 3 regions i.e. 'US', 'Europe' and 'Japan' by assigning these regions different color codes.
sns.pairplot(df, hue = 'brand')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, hue = 'cylinders')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, hue = 'year')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Q4. Create a heatmap for the entire data to study correlation between each of the columns.

# %%
# corr = sns.heatmap(df, annot = True, cmap = 'Blue')
# corr
# The above line of code will give error since some of the columns data type is object. To plot a matrix we need columns
# That have their datatype as 'float' and 'intiger' only. To do so, use the line of code given below:
# df_new = df.select_dtypes(include = ['int', 'float']).columns
#

# %%
df_new = df.select_dtypes(include = ['int', 'float']).columns
df_new
# Out:
# Index(['mpg', 'cylinders', 'hp', 'time-to-60', 'year'], dtype='object')

# %%
df_new = df[df_new]
df_new
# Out:
#       mpg  cylinders   hp  time-to-60  year
# 0    14.0          8  165          12  1972
# 1    31.9          4   71          14  1980
# 2    17.0          8  140          11  1971
# 3    15.0          8  150          10  1971
# 4    30.5          4   63          17  1978
# ..    ...        ...  ...         ...   ...
# 256  17.0          8  130          15  1980
# 257  36.1          4   60          16  1979
# 258  22.0          6  112          15  1983
# 259  18.0          6  100          16  1972
# 260  22.0          6  105          15  1977
#
# [261 rows x 5 columns]

# %%
sns.heatmap(df_new)
# Out:
# <Axes: >

# %%
corr = df_new.corr()
corr
# Out:
#                  mpg  cylinders        hp  time-to-60      year
# mpg         1.000000  -0.776710 -0.774905    0.509070  0.550441
# cylinders  -0.776710   1.000000  0.845155   -0.578161 -0.322239
# hp         -0.774905   0.845155  1.000000   -0.744873 -0.383869
# time-to-60  0.509070  -0.578161 -0.744873    1.000000  0.312311
# year        0.550441  -0.322239 -0.383869    0.312311  1.000000

# %%
sns.heatmap(corr, annot = True, cmap = 'BuPu', fmt = '.3f')
# annot=True: This argument ensures that the values in the heatmap are displayed as annotations on each cell
# .2f" is a format specifier that tells Python to display floating-point numbers with two decimal places
# Out:
# <Axes: >

# %% [markdown]
# ### Create a histogram for the following:
# ### a. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand.

# %% [markdown]
# ### Create line plots for the following:
# #### a. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight Ibs, mpg-weight lbs, cubic inches-weight Ibs.
